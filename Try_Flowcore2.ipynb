# %% [markdown]
# installation
# https://github.com/RGLab/ncdfFlow/issues/40
#
# meet problem when installing  ncdfFlow
# ```
# In file included from hdfFlow.c:1:0:
# hdfFlow.h:4:18: fatal error: hdf5.h: No such file or directory
# compilation terminated.
# /usr/lib/R/etc/Makeconf:159: recipe for target 'hdfFlow.o' failed
# ```

# %% [markdown]
# https://www.r-project.org/conferences/useR-2009/slides/LeMeur+Hahne+Sarkar+Gentleman.pdf

# %%
library(flowCore)
library(flowViz)
library(flowStats)
data(GvHD)
# Out:
# Error in library(flowStats): there is no package called ‘flowStats’
# Traceback:
#
# 1. library(flowStats)
# 2. stop(txt, domain = NA)

# %%
densityplot(~ `FSC-H`, GvHD[8:21],
    filter=curv1Filter("FSC-H"))
# Out:
# Error in curv1Filter("FSC-H"): could not find function "curv1Filter"
# Traceback:
#
# 1. densityplot(~`FSC-H`, GvHD[8:21], filter = curv1Filter("FSC-H"))
# 2. densityplot(~`FSC-H`, GvHD[8:21], filter = curv1Filter("FSC-H"))
# 3. .densityplot.adapor(x, data, ...)
# 4. .densityplot.flowSet.stack(x, data, plotType = plotType, ...)
# 5. eval.parent(ccall)
# 6. eval(expr, p)
# 7. eval(expr, p)
# 8. lattice::bwplot(x = name ~ sample | which, data = structure(list(
#  .     Patient = structure(c(2L, 2L, 2L, 2L, 2L, 2L, 2L, 3L, 3L,
#  .     3L, 3L, 3L, 3L, 3L), .Label = c("5", "6", "7", "9", "10"), class = "factor"),
#  .     Visit = structure(c(1L, 2L, 3L, 4L, 5L, 6L, 7L, 1L, 2L, 3L,
#  .     4L, 5L, 6L, 7L), .Label = c("1", "2", "3", "4", "5", "6",
#  .     "7"), class = "factor"), Days = c(-8L, 0L, 5L, 12L, 19L,
#  .     27L, 32L, -4L, 0L, 7L, 14L, 21L, 28L, 35L), Grade = c(3L,
#  .     3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L, 3L), name = c("s6a01",
# ...
